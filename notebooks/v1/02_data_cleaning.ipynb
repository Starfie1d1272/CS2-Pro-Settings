# %%
# ==========================================
# Phase 2 - Cell 1: 数据加载 → 战队过滤 → 现役选手精确筛选
# 白名单: HLTV Top 30 (2026-05-04) + 老牌豪门 + 赛区代表 + 明星选手队
# 选手范围: 仅保留 HLTV 现役首发名单，排除替补/教练/旧阵容
# 输入: data/cs2_pro_detailed_RAW.csv
# 输出: df_filtered (仅含现役首发选手)
# ==========================================
import pandas as pd

raw_csv = "data/cs2_pro_detailed_RAW.csv"
df = pd.read_csv(raw_csv, low_memory=False)
print(f"原始数据: {len(df)} 人, {df['Team'].nunique()} 队")

# Step 1: 战队白名单 (41 队, 64 个名称变体)
team_whitelist = ['Team Vitality', 'Vitality', 'Natus Vincere', 'NAVI', 'FURIA', 'FURIA Esports', 'Aurora', 'Aurora Gaming', 'Falcons Esports', 'Falcons', 'Team Falcons', 'Team Spirit', 'Spirit', 'PARIVISION', 'The Mongolz', 'The MongolZ', 'Astralis', 'FUT Esports', 'FUT', 'MOUZ', 'G2 Esports', 'G2', 'FaZe Clan', 'FaZe', 'GamerLegion', '3DMAX', 'B8 Esports', 'B8', 'Legacy', '9z Team', '9z', 'Monte', 'M80', 'Alliance', 'TyLoo', 'TYLOO', 'BetBoom Team', 'BetBoom', 'HEROIC', 'Team Liquid', 'Liquid', 'NRG', 'MIBR', 'EYEBALLERS', 'Ninjas in Pyjamas', 'NIP', 'BIG', 'Fnatic', 'fnatic', 'OG Esports', 'OG', 'Imperial Esports', 'Imperial', '100 Thieves', '100T', 'Lynn Vision', 'Lynn Vision Gaming', 'Rare Atom', 'FlyQuest', 'paiN Gaming', 'paiN', 'BC.Game', 'Passion UA', 'Gentle Mates']

df_team = df[df['Team'].notna() & df['Team'].isin(team_whitelist)].copy()
print(f"战队过滤: {len(df_team)} 人, {df_team['Team'].nunique()} 队")

# Step 2: 现役首发选手精确筛选 (大小写不敏感, 含 HLTV↔prosettings 别名)
player_whitelist_lower = {"910", "adamb", "afro", "ag1l", "aleksib", "alex", "alex666", "apex", "arrozdoce", "art", "avid", "azuwu", "azuww", "b1t", "belchonokk", "biguzera", "blamef", "blitz", "bobeksde", "bodyy", "boombi4", "boombl4", "br0", "br4tko", "brnz4n", "broky", "bymas", "c4llm3su3", "cadian", "cairne", "chelo", "chengking", "childking", "chr1zn", "cmtry", "cobra", "cobrazera", "d1ledez", "dav1g", "decenty", "dem0n", "device", "dex", "dgt", "donk", "dumau", "dziugss", "electronic", "elige", "emiliaqaq", "eraa", "esenthial", "ex3rcice", "ex3rciice", "fallen", "faven", "fear", "flamez", "frozen", "gizmy", "gr1ks", "graviti", "grim", "heavygod", "hooxi", "huasopeek", "hunter", "hunter-", "hypex", "im", "ins", "insani", "jabbi", "jackasmo", "jambo", "jame", "jamyoung", "jba", "jcobbb", "jdc", "jee", "jks", "jl", "jt", "jw", "karrigan", "kensizor", "kl1m", "krabeni", "krazy", "krimz", "kscerato", "kvem", "kyousuke", "l1hang", "lake", "latto", "launx", "levi", "lnz", "luchov", "lucky", "m0nesy", "magixx", "magnojez", "mail09", "maj3r", "maka", "makazze", "malbsmd", "martinezsa", "matys", "max", "maxster", "mercury", "meyern", "mezii", "misutaa", "misutaaa", "molodoy", "monesy", "mopoz", "moseyuh", "mzinho", "n1ssim", "naf", "nertz", "nettik", "nicx", "niko", "nilo", "nitr0", "nixc", "nota", "noway", "npl", "osee", "phzy", "piriajr", "poii", "poiii", "pr", "rain", "rainmaker", "rainwaker", "rez", "ro1f", "ropz", "ryu", "s1mple", "s1n", "s1ren", "s1zzi", "saadzin", "saffee", "sausol", "sdy", "senzu", "sh1ro", "sirah", "siuhy", "sjuush", "slaxz", "slaxz-", "snappi", "snax", "snow", "sonic", "soulfly", "spinx", "spooke", "staehr", "starry", "stavn", "story", "summer", "sunpayus", "susp", "swisher", "tabsen", "tauson", "techno", "techno4k", "teses", "tiger", "tn1r", "torzsi", "try", "twist", "twistzz", "ultimate", "upe", "venomzera", "vexite", "vini", "vsm", "w0nderful", "westmelon", "wicadia", "woxic", "xantares", "xelex", "xertion", "xfl0ud", "xfloud", "xielo", "xkacpersky", "yekindar", "yuurih", "yxngstxr", "z4kr", "zero", "zont1x", "zorte", "zweih", "zywoo"}

df_team['Player_lower'] = df_team['Player'].str.lower()
df_filtered = df_team[df_team['Player_lower'].isin(player_whitelist_lower)].copy()
df_filtered = df_filtered.drop(columns=['Player_lower'])

excluded = len(df_team) - len(df_filtered)
if excluded > 0:
    print(f"选手过滤: {len(df_filtered)} 人 (排除 {excluded} 名替补/教练/旧阵容)")

df_filtered[['Player', 'Team', 'DPI', 'Sensitivity', 'Resolution']].head(10)

# %%
# ==========================================
# Phase 2 - Cell 2: 数值清洗 + 质检去重 → Master.csv
# 输入: df_filtered
# 输出: data/cs2_pro_2026_Active_Master.csv
# ==========================================
import pandas as pd
import numpy as np
import re

# 1. 聚焦关键列
desired_columns = [
    'Player', 'Team', 'DPI', 'Sensitivity', 'eDPI', 'Zoom Sensitivity',
    'Hz', 'Resolution', 'Aspect Ratio', 'Scaling Mode'
]
actual_columns = [col for col in desired_columns if col in df_filtered.columns]
df_clean = df_filtered[actual_columns].copy()

# 2. 数值化（处理 1,200 / 400dpi 等混合格式）
def clean_numeric_text(val):
    if pd.isna(val):
        return np.nan
    val_str = str(val).replace(',', '').replace(' ', '')
    match = re.search(r'[\d\.]+', val_str)
    return float(match.group()) if match else np.nan

numeric_cols = ['DPI', 'Sensitivity', 'eDPI', 'Zoom Sensitivity', 'Hz']
for col in numeric_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].apply(clean_numeric_text)

# 3. 回填缺失 eDPI
if 'eDPI' in df_clean.columns:
    mask = df_clean['eDPI'].isna() & df_clean['DPI'].notna() & df_clean['Sensitivity'].notna()
    df_clean.loc[mask, 'eDPI'] = df_clean.loc[mask, 'DPI'] * df_clean.loc[mask, 'Sensitivity']

# 4. 拆解分辨率
if 'Resolution' in df_clean.columns:
    res_df = df_clean['Resolution'].astype(str).str.extract(r'(\d+)x(\d+)').astype(float)
    df_clean['Res_Width'] = res_df[0]
    df_clean['Res_Height'] = res_df[1]

# 5. 数据质检
before_qc = len(df_clean)
df_clean = df_clean.dropna(subset=['eDPI', 'Resolution']).copy()
df_clean = df_clean[df_clean['Player'].str.lower() != df_clean['Team'].str.lower()]
df_clean['Player_lower'] = df_clean['Player'].str.lower()
df_clean = df_clean.drop_duplicates(subset=['Player_lower'], keep='first')
df_clean = df_clean.drop(columns=['Player_lower'])

print(f"🛡️ 质检: {before_qc} → {len(df_clean)} 人 (剔除 {before_qc - len(df_clean)} 条脏数据)")

# 6. 导出
master_csv = "data/cs2_pro_2026_Active_Master.csv"
df_clean.to_csv(master_csv, index=False, encoding='utf-8-sig')
print(f"💾 已保存: {master_csv} ({len(df_clean.columns)} 列)")
df_clean.head(5)

# %%
# ==========================================
# Phase 2 - Cell 3: 特征增强 (RAW 字段回填) → Final.csv
# 输入: df_clean + data/cs2_pro_detailed_RAW.csv
# 输出: data/cs2_pro_2026_Active_Final.csv
# ==========================================
import pandas as pd

df_raw = pd.read_csv('data/cs2_pro_detailed_RAW.csv', low_memory=False)

target_columns = [
    # 画面与显示
    'Player', 'Brightness', 'Display Mode', 'V-Sync', 'NVIDIA Reflex Low Latency',
    'NVIDIA G-Sync', 'Maximum FPS In Game', 'Refresh Rate',
    # 画质细节
    'Model / Texture Detail', 'Shader Detail', 'Particle Detail',
    'Ambient Occlusion', 'Global Shadow Quality',
    'Multisampling Anti-Aliasing Mode', 'Texture Filtering Mode',
    # 准星
    'Style', 'Dot', 'Length', 'Thickness', 'Gap', 'Outline',
    'Outlinethickness', 'Color', 'Follow Recoil', 'Red', 'Green', 'Blue',
    # 持枪视角
    'FOV', 'Offset X', 'Offset Y', 'Offset Z', 'Presetpos',
    # 雷达 & HUD
    'Radar Centers The Player', 'Radar is Rotating', 'Radar Map Zoom',
    'HUD Scale', 'HUD Color',
    # 鼠标
    'Windows Sensitivity',
]

available_cols = [c for c in target_columns if c in df_raw.columns]
df_features = df_raw[available_cols].drop_duplicates(subset=['Player'])
df_pro = pd.merge(df_clean, df_features, on='Player', how='left', suffixes=('', '_new'))

# 字段覆盖
for col in available_cols:
    if col != 'Player' and col + '_new' in df_pro.columns:
        df_pro[col] = df_pro[col + '_new']
        df_pro = df_pro.drop(columns=[col + '_new'])

# Unknown 填充
fill_cols = ['Display Mode', 'V-Sync', 'NVIDIA Reflex Low Latency', 'NVIDIA G-Sync',
             'Model / Texture Detail', 'Shader Detail', 'Particle Detail', 'Ambient Occlusion',
             'Multisampling Anti-Aliasing Mode', 'Texture Filtering Mode',
             'Follow Recoil', 'HUD Color', 'Style', 'Color', 'Dot', 'Outline']
for col in fill_cols:
    if col in df_pro.columns:
        df_pro[col] = df_pro[col].fillna('Unknown')

# 强制数值化
numeric_force = ['eDPI', 'Hz', 'DPI', 'Sensitivity', 'Red', 'Green', 'Blue',
                 'Offset X', 'Offset Y', 'Offset Z', 'FOV', 'Radar Map Zoom',
                 'Gap', 'Length', 'Thickness']
for col in numeric_force:
    if col in df_pro.columns:
        df_pro[col] = pd.to_numeric(df_pro[col], errors='coerce')

final_csv = "data/cs2_pro_2026_Active_Final.csv"
df_pro.to_csv(final_csv, index=False, encoding='utf-8-sig')
print(f"💾 已保存: {final_csv}")
print(f"📊 {len(df_pro)} 人 × {len(df_pro.columns)} 维特征")
df_pro.head(5)

# %%
# ==========================================
# Phase 2 - Cell 4: 数据就绪检查
# ==========================================
import pandas as pd

df_pro = pd.read_csv('data/cs2_pro_2026_Active_Final.csv')

print(f"✅ 最终数据集: {len(df_pro)} 名选手, {len(df_pro.columns)} 个维度")
print(f"🏢 战队数: {df_pro['Team'].nunique()}")

# 核心字段缺失检查
key_fields = ['eDPI', 'DPI', 'Sensitivity', 'Resolution', 'Hz']
missing = {f: df_pro[f].isna().sum() for f in key_fields if f in df_pro.columns}
if any(missing.values()):
    for f, cnt in missing.items():
        if cnt > 0:
            print(f"  ⚠️ {f}: {cnt} 条缺失")
else:
    print("✅ 核心字段完整，可进入 03_final_report 生成图表")
